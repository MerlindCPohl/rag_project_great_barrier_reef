# %%
import pymupdf as pdf
import pickle
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

# Path to the GBR study PDF
pdf_path = "Access Economics 2007 Economic contribution of Great Barrier Reef Marine Park 2005-2006 Kopie.pdf"
document_output_path = "gbr_extracted_text.txt"
vector_store_path = "gbr_faiss_store.pkl"

# Page selection: 6 – 86 
selected_pages = list(range(5, 87))

# Embedding model selection: BGE-M3 from BAAI, which is a multilingual model 
embedding = HuggingFaceBgeEmbeddings(
    model_name="BAAI/bge-m3",
    model_kwargs={"device": "cpu"},         
    encode_kwargs={"normalize_embeddings": True},
    query_instruction="",                  
)
# Out:
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 79019.60it/s]
